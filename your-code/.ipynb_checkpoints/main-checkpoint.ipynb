# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import numpy as np
from functools import reduce
from scipy import stats as st
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
#Hay dos columnas con tipo object y una columna numérica
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
ny = temp['State'] == 'New York'
NY = temp[ny]
NY
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
round(NY['Temperature'].mean(),2)
# Out:
# 10.74

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
at = temp['Temperature'] > 15
above_temp = temp[at]
above_temp
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
above_temp.City
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp.loc[(temp.Temperature>15) & (temp.Temperature<20)]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
temp.groupby(['State']).agg([np.mean,np.std])
# Out:
#             Temperature
#                    mean       std
# State
# Connecticut   15.833333  1.964186
# New Jersey    21.111111  1.571348
# New York      10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee = pd.read_csv('employee.csv')

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
# Dataframe con cinco columnas de tipo string/object y dos numéricas
employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
#sns.countplot(x=employee.Department);
sns.histplot(x=employee.Department, color='b');

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
round(employee['Salary'].mean(),2)
# Out:
# 48.89

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
employee.loc[employee.loc[:,'Salary'] == 30]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee.loc[employee.loc[:,'Name'] == 'David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
pd.DataFrame(employee.loc[employee.loc[:,'Name'] == 'David'].Salary)
# Out:
#    Salary
# 2      30

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee.loc[employee.loc[:,'Title'] == 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee.loc[(employee['Title'] == 'associate') & (employee['Salary'] > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
employee.groupby('Years').agg({'Salary': 'mean'})
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
employee.groupby('Title').agg({'Salary': 'mean'})
# Out:
#               Salary
# Title
# VP         70.000000
# analyst    32.500000
# associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
sns.boxplot(x=employee.Salary, color='y');

# %%
# print first quartile here
np.quantile(employee.Salary, 0.25)
# Out:
# 35.0

# %%
# print third quartile here
np.quantile(employee.Salary, 0.75)
# Out:
# 60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
#Si es diferente, es más alta la media de los salarios de los hombres
employee.groupby(['Gender']).agg({'Salary':'mean'})
# Out:
#         Salary
# Gender
# F         47.5
# M         50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
employee.groupby(['Department']).agg({np.mean,np.min,np.max})
# Out:
#                Years           Salary
#                 mean amax amin   mean amax amin
# Department
# HR          4.666667    8    2  45.00   70   30
# IT          4.500000    8    1  48.75   70   30
# Sales       2.500000    3    2  55.00   55   55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here
employee.groupby(['Department']).max().Salary
employee.groupby(['Department']).max().Salary
# Out:
# Department
# HR       70
# IT       70
# Sales    55
# Name: Salary, dtype: int64

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
pd.set_option('display.max_columns', None)

# %%
# your answer here
orders = pd.read_csv('Orders.zip')
orders[:10]
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
# 5           5     536365     22752  2010     12    3     8
# 6           6     536365     21730  2010     12    3     8
# 7           7     536366     22633  2010     12    3     8
# 8           8     536366     22632  2010     12    3     8
# 9           9     536367     84879  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
# 5         set 7 babushka nesting boxes         2  2010-12-01 08:26:00
# 6    glass star frosted t-light holder         6  2010-12-01 08:26:00
# 7               hand warmer union jack         6  2010-12-01 08:28:00
# 8            hand warmer red polka dot         6  2010-12-01 08:28:00
# 9        assorted colour bird ornament        32  2010-12-01 08:34:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# 2       2.75       17850  United Kingdom         22.00
# 3       3.39       17850  United Kingdom         20.34
# 4       3.39       17850  United Kingdom         20.34
# 5       7.65       17850  United Kingdom         15.30
# 6       4.25       17850  United Kingdom         25.50
# 7       1.85       17850  United Kingdom         11.10
# 8       1.85       17850  United Kingdom         11.10
# 9       1.69       13047  United Kingdom         54.08

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# 25%         2.000000      11.000000       2.000000       1.250000
# 50%         3.000000      13.000000       6.000000       1.950000
# 75%         5.000000      14.000000      12.000000       3.750000
# max         7.000000      20.000000   80995.000000    8142.750000
#
#           CustomerID   amount_spent
# count  397924.000000  397924.000000
# mean    15294.315171      22.394749
# std      1713.169877     309.055588
# min     12346.000000       0.000000
# 25%     13969.000000       4.680000
# 50%     15159.000000      11.800000
# 75%     16795.000000      19.800000
# max     18287.000000  168469.600000

# %%
# your answer here

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
round(orders['amount_spent'].mean(),2)
# Out:
# 22.39

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders['amount_spent'].max()
# Out:
# 168469.6

# %%
# your answer here
orders['amount_spent'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
españa = orders.loc[orders.loc[:,'Country'] == 'Spain']
españa[:10]
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250         6421     536944     22383  2010     12    5    12
# 4251         6422     536944     22384  2010     12    5    12
# 4252         6423     536944     20727  2010     12    5    12
# 4253         6424     536944     20725  2010     12    5    12
# 4254         6425     536944     20728  2010     12    5    12
# 13974       21565     538095     22504  2010     12    4    14
# 13975       21566     538095     22212  2010     12    4    14
# 13976       21567     538095     22953  2010     12    4    14
# 13977       21568     538095     84818  2010     12    4    14
# 13978       21569     538095     21114  2010     12    4    14
#
#                               Description  Quantity          InvoiceDate  \
# 4250              lunch bag suki  design         70  2010-12-03 12:20:00
# 4251              lunch bag pink polkadot       100  2010-12-03 12:20:00
# 4252              lunch bag  black skull.        60  2010-12-03 12:20:00
# 4253              lunch bag red retrospot        70  2010-12-03 12:20:00
# 4254                  lunch bag cars blue       100  2010-12-03 12:20:00
# 13974         cabin bag vintage retrospot         1  2010-12-09 14:55:00
# 13975          four hook  white lovebirds         1  2010-12-09 14:55:00
# 13976  birthday party cordon barrier tape         1  2010-12-09 14:55:00
# 13977             danish rose photo frame         1  2010-12-09 14:55:00
# 13978       lavender scented fabric heart         5  2010-12-09 14:55:00
#
#        UnitPrice  CustomerID Country  amount_spent
# 4250        1.65       12557   Spain        115.50
# 4251        1.45       12557   Spain        145.00
# 4252        1.65       12557   Spain         99.00
# 4253        1.65       12557   Spain        115.50
# 4254        1.45       12557   Spain        145.00
# 13974      29.95       17097   Spain         29.95
# 13975       2.10       17097   Spain          2.10
# 13976       1.25       17097   Spain          1.25
# 13977       2.55       17097   Spain          2.55
# 13978       1.25       17097   Spain          6.25

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
españa['Country'].value_counts()
# Out:
# Spain    2485
# Name: Country, dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
orders.loc[orders.loc[:,'Quantity'] > 50][:10]
# Out:
#      Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 46           46     536371     22086  2010     12    3     9
# 83           83     536376     21733  2010     12    3     9
# 96           96     536378     21212  2010     12    3     9
# 102         102     536378    85071B  2010     12    3     9
# 174         176     536386    85099C  2010     12    3     9
# 175         177     536386    85099B  2010     12    3     9
# 176         178     536387     79321  2010     12    3     9
# 177         179     536387     22780  2010     12    3     9
# 178         180     536387     22779  2010     12    3     9
# 179         181     536387     22466  2010     12    3     9
#
#                             Description  Quantity          InvoiceDate  \
# 46      paper chain kit 50's christmas         80  2010-12-01 09:00:00
# 83     red hanging heart t-light holder        64  2010-12-01 09:32:00
# 96      pack of 72 retrospot cake cases       120  2010-12-01 09:37:00
# 102  red charlie+lola personal doorsign        96  2010-12-01 09:37:00
# 174      jumbo  bag baroque black white       100  2010-12-01 09:57:00
# 175             jumbo bag red retrospot       100  2010-12-01 09:57:00
# 176                       chilli lights       192  2010-12-01 09:58:00
# 177      light garland butterfiles pink       192  2010-12-01 09:58:00
# 178          wooden owls light garland        192  2010-12-01 09:58:00
# 179       fairy tale cottage nightlight       432  2010-12-01 09:58:00
#
#      UnitPrice  CustomerID         Country  amount_spent
# 46        2.55       13748  United Kingdom        204.00
# 83        2.55       15291  United Kingdom        163.20
# 96        0.42       14688  United Kingdom         50.40
# 102       0.38       14688  United Kingdom         36.48
# 174       1.65       16029  United Kingdom        165.00
# 175       1.65       16029  United Kingdom        165.00
# 176       3.82       16029  United Kingdom        733.44
# 177       3.37       16029  United Kingdom        647.04
# 178       3.37       16029  United Kingdom        647.04
# 179       1.45       16029  United Kingdom        626.40

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
españa.loc[españa.loc[:,'Quantity'] > 50][:10]
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250         6421     536944     22383  2010     12    5    12
# 4251         6422     536944     22384  2010     12    5    12
# 4252         6423     536944     20727  2010     12    5    12
# 4253         6424     536944     20725  2010     12    5    12
# 4254         6425     536944     20728  2010     12    5    12
# 32454       52416     540785    84997B  2011      1    2    11
# 32455       52417     540785    84997D  2011      1    2    11
# 32456       52418     540785    84997C  2011      1    2    11
# 32457       52419     540785    84997A  2011      1    2    11
# 91155      136767     547972     22383  2011      3    1    16
#
#                               Description  Quantity          InvoiceDate  \
# 4250              lunch bag suki  design         70  2010-12-03 12:20:00
# 4251              lunch bag pink polkadot       100  2010-12-03 12:20:00
# 4252              lunch bag  black skull.        60  2010-12-03 12:20:00
# 4253              lunch bag red retrospot        70  2010-12-03 12:20:00
# 4254                  lunch bag cars blue       100  2010-12-03 12:20:00
# 32454   red 3 piece retrospot cutlery set       144  2011-01-11 11:39:00
# 32455   pink 3 piece polkadot cutlery set       360  2011-01-11 11:39:00
# 32456   blue 3 piece polkadot cutlery set       360  2011-01-11 11:39:00
# 32457  green 3 piece polkadot cutlery set       144  2011-01-11 11:39:00
# 91155              lunch bag suki design        150  2011-03-28 16:41:00
#
#        UnitPrice  CustomerID Country  amount_spent
# 4250        1.65       12557   Spain        115.50
# 4251        1.45       12557   Spain        145.00
# 4252        1.65       12557   Spain         99.00
# 4253        1.65       12557   Spain        115.50
# 4254        1.45       12557   Spain        145.00
# 32454       3.39       12557   Spain        488.16
# 32455       3.39       12557   Spain       1220.40
# 32456       3.39       12557   Spain       1220.40
# 32457       3.39       12557   Spain        488.16
# 91155       1.45       12557   Spain        217.50

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
orders.loc[(orders.loc[:,'UnitPrice'] == 0)].sample(10)
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 273926      379913     569716     22778  2011     10    4     8
# 256263      358655     568158      PADS  2011      9    7    12
# 223932      314746     564651     23268  2011      8    5    14
# 358629      485985     577696         M  2011     11    1    11
# 329006      446793     574920     22899  2011     11    1    16
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 352746      479079     577129     22464  2011     11    4    19
# 208950      298054     562973     23157  2011      8    4    11
# 320407      436961     574252         M  2011     11    4    13
#
#                                 Description  Quantity          InvoiceDate  \
# 273926                   glass cloche small         2  2011-10-06 08:17:00
# 256263           pads to match all cushions         1  2011-09-25 12:22:00
# 223932  set of 2 ceramic christmas reindeer       192  2011-08-26 14:19:00
# 358629                               manual         1  2011-11-21 11:57:00
# 329006         children's apron dolly girl          1  2011-11-07 16:34:00
# 25379              regency cakestand 3 tier        10  2010-12-21 13:45:00
# 29080               paper bunting retrospot        24  2011-01-06 16:41:00
# 352746          hanging metal heart lantern         4  2011-11-17 19:52:00
# 208950           set of 6 nativity magnets        240  2011-08-11 11:42:00
# 320407                               manual         1  2011-11-03 13:24:00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 273926        0.0       15804  United Kingdom           0.0
# 256263        0.0       16133  United Kingdom           0.0
# 223932        0.0       14646     Netherlands           0.0
# 358629        0.0       16406  United Kingdom           0.0
# 329006        0.0       13985  United Kingdom           0.0
# 25379         0.0       14911            EIRE           0.0
# 29080         0.0       13081  United Kingdom           0.0
# 352746        0.0       15602  United Kingdom           0.0
# 208950        0.0       14911            EIRE           0.0
# 320407        0.0       12437          France           0.0

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
lunch_bag = orders.loc[orders['Description'].str.contains('lunch bag')]
lunch_bag.sample(5)
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 154916      221998     556304     22382  2011      6    5    10
# 232893      328729     565803     22383  2011      9    3    10
# 212448      302169     563377     20727  2011      8    2    10
# 183582      263676     560025     23209  2011      7    4    13
# 373044      505314     579011     22383  2011     11    1     9
#
#                        Description  Quantity          InvoiceDate  UnitPrice  \
# 154916  lunch bag spaceboy design         20  2011-06-10 10:29:00       1.65
# 232893      lunch bag suki design         20  2011-09-07 10:38:00       1.65
# 212448     lunch bag  black skull.        10  2011-08-16 10:44:00       1.65
# 183582   lunch bag doiley pattern          1  2011-07-14 13:00:00       1.65
# 373044      lunch bag suki design         10  2011-11-28 09:40:00       1.65
#
#         CustomerID         Country  amount_spent
# 154916       12840  United Kingdom         33.00
# 232893       17735  United Kingdom         33.00
# 212448       15002  United Kingdom         16.50
# 183582       18283  United Kingdom          1.65
# 373044       15078  United Kingdom         16.50

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
lunch_bag.loc[lunch_bag['year'] == 2011].sample(5)
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 100198      149074     549274     20726  2011      4    4    13
# 49431        80430     543040     20725  2011      2    3    17
# 122595      179321     552269     23206  2011      5    7    11
# 189255      271344     560690     22382  2011      7    3    12
# 159423      227974     556912     20725  2011      6    3    13
#
#                        Description  Quantity          InvoiceDate  UnitPrice  \
# 100198          lunch bag woodland        10  2011-04-07 13:07:00       1.65
# 49431      lunch bag red retrospot         1  2011-02-02 17:06:00       1.65
# 122595      lunch bag apple design         1  2011-05-08 11:52:00       1.65
# 189255  lunch bag spaceboy design         10  2011-07-20 12:00:00       1.65
# 159423     lunch bag red retrospot         1  2011-06-15 13:26:00       1.65
#
#         CustomerID         Country  amount_spent
# 100198       12721          France         16.50
# 49431        17337  United Kingdom          1.65
# 122595       16121  United Kingdom          1.65
# 189255       16807  United Kingdom         16.50
# 159423       15005  United Kingdom          1.65

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
agosto = orders.loc[orders['month'] == 8]
agosto.sample(5)
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 212223      301938     563361     84755  2011      8    1    15
# 208438      296610     562926     22457  2011      8    3    14
# 211086      300781     563213    85099B  2011      8    7    12
# 218952      309085     564061     20828  2011      8    1    14
# 202666      289309     562263    47504H  2011      8    3    15
#
#                                 Description  Quantity          InvoiceDate  \
# 212223  colour glass t-light holder hanging        16  2011-08-15 15:17:00
# 208438      natural slate heart chalkboard          6  2011-08-10 14:55:00
# 211086              jumbo bag red retrospot         2  2011-08-14 12:55:00
# 218952              glitter butterfly clips         3  2011-08-22 14:38:00
# 202666           english rose spirit level          2  2011-08-03 15:45:00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 212223       0.65       15315  United Kingdom         10.40
# 208438       2.95       17512  United Kingdom         17.70
# 211086       2.08       16115  United Kingdom          4.16
# 218952       2.55       14505  United Kingdom          7.65
# 202666       0.79       17514  United Kingdom          1.58

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
pd.DataFrame(orders[orders.month == 8]['Country'].value_counts())
# Out:
#                  Country
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
orders.groupby(['Country']).agg({'amount_spent': 'mean'})
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# Portugal                 22.872702
# RSA                      17.281207
# Saudi Arabia             16.213333
# Singapore                95.852658
# Spain                    24.779521
# Sweden                   85.096075
# Switzerland              30.642752
# USA                      20.002179
# United Arab Emirates     27.974706
# United Kingdom           20.625073
# Unspecified              10.930615

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
orders.loc[orders.loc[:,'UnitPrice'] == orders.UnitPrice.max()]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 118352      173382     551697      POST  2011      5    2    13     postage
#
#         Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352         1  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders.groupby(['year']).agg({'amount_spent': 'mean'})
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
